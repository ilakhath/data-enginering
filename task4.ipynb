# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"D:\projects_param\data_enginering_s\delta_calculation_19_02_2023\dslot\WAVE-DNCA163584-UDPV3-1-ITER1_20230126_122707_F54562511.xlsx")

# %%
df
# Out:
#                    TIME_STAMP         Lon        Lat  \
# 0     2023-01-26 12:27:07.606 -122.004860  37.326351
# 1     2023-01-26 12:27:07.607 -122.004860  37.326351
# 2     2023-01-26 12:27:07.607 -122.004860  37.326351
# 3     2023-01-26 12:27:07.607 -122.004860  37.326351
# 4     2023-01-26 12:27:07.607 -122.004860  37.326351
# ...                       ...         ...        ...
# 69071 2023-01-26 12:28:22.942 -122.004868  37.326401
# 69072 2023-01-26 12:28:22.992 -122.004868  37.326401
# 69073 2023-01-26 12:28:22.992 -122.004868  37.326401
# 69074 2023-01-26 12:28:22.993 -122.004868  37.326401
# 69075 2023-01-26 12:28:23.925 -122.004868  37.326401
#
#        Qualcomm 5G-NR MAC PDSCH Status[Per Slot] PCell System Frame Number  \
# 0                                                  967.0
# 1                                                  968.0
# 2                                                  968.0
# 3                                                  969.0
# ...

# %%
df.shape
# Out:
# (69076, 25)

# %%
df.head()
# Out:
#                TIME_STAMP        Lon        Lat  \
# 0 2023-01-26 12:27:07.606 -122.00486  37.326351
# 1 2023-01-26 12:27:07.607 -122.00486  37.326351
# 2 2023-01-26 12:27:07.607 -122.00486  37.326351
# 3 2023-01-26 12:27:07.607 -122.00486  37.326351
# 4 2023-01-26 12:27:07.607 -122.00486  37.326351
#
#    Qualcomm 5G-NR MAC PDSCH Status[Per Slot] PCell System Frame Number  \
# 0                                              967.0
# 1                                              968.0
# 2                                              968.0
# 3                                              969.0
# 4                                              969.0
#
#    Qualcomm 5G-NR MAC PDSCH Status[Per Slot] PCell Slot Number  \
# 0                                               10.0
# 1                                                9.0
# 2                                               11.0
# 3                                                0.0
# ...

# %%
df_col=df[['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number',
           'Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num']]

# %%
df_col
# Out:
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 69071                                                NaN
# 69072                                                NaN
# 69073                                                NaN
# 69074                                                NaN
# 69075                                                NaN
#
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# ...

# %%
df.shape
# Out:
# (69076, 25)

# %%
df_fil=df_col.dropna(subset=['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number','Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num'])

# %%
df_fil
# Out:
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number  \
# 364                                                232.0
# 365                                                232.0
# 366                                                232.0
# 367                                                232.0
# 368                                                232.0
# ...                                                  ...
# 68973                                               58.0
# 68974                                               58.0
# 68975                                               58.0
# 68976                                               58.0
# 68977                                               58.0
#
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num
# 364                                                  0.0
# 365                                                  1.0
# 366                                                  2.0
# ...

# %%
df_fil.shape
# Out:
# (24463, 2)

# %%
#checking after removed null values
df_fil.isnull().sum()
# Out:
# Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number    0
# Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num           0
# dtype: int64

# %%
df_fil['current_line']=(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number']*10)+(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num']*0.5)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_3172\238001511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['current_line']=(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number']*10)+(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num']*0.5)

# %%
df_fil
# Out:
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number  \
# 364                                                232.0
# 365                                                232.0
# 366                                                232.0
# 367                                                232.0
# 368                                                232.0
# ...                                                  ...
# 68973                                               58.0
# 68974                                               58.0
# 68975                                               58.0
# 68976                                               58.0
# 68977                                               58.0
#
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num  \
# 364                                                  0.0
# 365                                                  1.0
# 366                                                  2.0
# ...

# %%
df_fil.shape
# Out:
# (24463, 3)

# %%
df_fil['previous_line']=(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number'].shift(1)*10)+(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num'].shift(1)*0.5)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_3172\3589825566.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['previous_line']=(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number'].shift(1)*10)+(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num'].shift(1)*0.5)

# %%
df_fil
# Out:
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number  \
# 364                                                232.0
# 365                                                232.0
# 366                                                232.0
# 367                                                232.0
# 368                                                232.0
# ...                                                  ...
# 68973                                               58.0
# 68974                                               58.0
# 68975                                               58.0
# 68976                                               58.0
# 68977                                               58.0
#
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num  \
# 364                                                  0.0
# 365                                                  1.0
# 366                                                  2.0
# ...

# %%
df_fil.shape
# Out:
# (24463, 4)

# %%
df_fil.head()
# Out:
#      Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number  \
# 364                                              232.0
# 365                                              232.0
# 366                                              232.0
# 367                                              232.0
# 368                                              232.0
#
#      Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num  \
# 364                                                0.0
# 365                                                1.0
# 366                                                2.0
# 367                                                3.0
# 368                                                4.0
#
#      current_line  previous_line  delta  Lte_Delta_Scell (RX_on)
# 364        2320.0            NaN    NaN                      NaN
# 365        2320.5         2320.0    0.5                  12560.5
# ...

# %%
df_fil['delta']=(df_fil['current_line']-df_fil['previous_line'])/1.0
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_3172\4162976678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['delta']=(df_fil['current_line']-df_fil['previous_line'])/1.0

# %%
df_fil['Lte_Delta_Scell (RX_on)']=np.where(df_fil.current_line> df_fil.previous_line,((1023*10+19*0.5)-(df_fil.previous_line)) + (df_fil.current_line) / 0.5,((1023*10+9*1)-(df_fil.previous_line)) + (df_fil.current_line) / 1.0)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_3172\3131930914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['Lte_Delta_Scell (RX_on)']=np.where(df_fil.current_line> df_fil.previous_line,((1023*10+19*0.5)-(df_fil.previous_line)) + (df_fil.current_line) / 0.5,((1023*10+9*1)-(df_fil.previous_line)) + (df_fil.current_line) / 1.0)

# %%
df_fil
# Out:
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number  \
# 364                                                232.0
# 365                                                232.0
# 366                                                232.0
# 367                                                232.0
# 368                                                232.0
# ...                                                  ...
# 68973                                               58.0
# 68974                                               58.0
# 68975                                               58.0
# 68976                                               58.0
# 68977                                               58.0
#
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num  \
# 364                                                  0.0
# 365                                                  1.0
# 366                                                  2.0
# ...

# %%
df_fil.shape
# Out:
# (24463, 5)

# %%
df_fil.head()
# Out:
#      Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number  \
# 364                                              232.0
# 365                                              232.0
# 366                                              232.0
# 367                                              232.0
# 368                                              232.0
#
#      Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num  \
# 364                                                0.0
# 365                                                1.0
# 366                                                2.0
# 367                                                3.0
# 368                                                4.0
#
#      current_line  previous_line  delta  Lte_Delta_Scell (RX_on)
# 364        2320.0            NaN    NaN                      NaN
# 365        2320.5         2320.0    0.5                  12560.5
# ...

# %%
df_fil
# Out:
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] System Frame Number  \
# 364                                                232.0
# 365                                                232.0
# 366                                                232.0
# 367                                                232.0
# 368                                                232.0
# ...                                                  ...
# 68973                                               58.0
# 68974                                               58.0
# 68975                                               58.0
# 68976                                               58.0
# 68977                                               58.0
#
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication SCell[1] Subframe Num  \
# 364                                                  0.0
# 365                                                  1.0
# 366                                                  2.0
# ...
