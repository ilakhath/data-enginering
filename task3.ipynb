# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_excel(r"D:\projects_param\data_enginering_s\delta_calculation_19_02_2023\dslot\WAVE-DNCA163584-UDPV3-1-ITER1_20230126_122707_F54562511.xlsx")

# %%
df
# Out:
#                    TIME_STAMP         Lon        Lat  \
# 0     2023-01-26 12:27:07.606 -122.004860  37.326351
# 1     2023-01-26 12:27:07.607 -122.004860  37.326351
# 2     2023-01-26 12:27:07.607 -122.004860  37.326351
# 3     2023-01-26 12:27:07.607 -122.004860  37.326351
# 4     2023-01-26 12:27:07.607 -122.004860  37.326351
# ...                       ...         ...        ...
# 69071 2023-01-26 12:28:22.942 -122.004868  37.326401
# 69072 2023-01-26 12:28:22.992 -122.004868  37.326401
# 69073 2023-01-26 12:28:22.992 -122.004868  37.326401
# 69074 2023-01-26 12:28:22.993 -122.004868  37.326401
# 69075 2023-01-26 12:28:23.925 -122.004868  37.326401
#
#        Qualcomm 5G-NR MAC PDSCH Status[Per Slot] PCell System Frame Number  \
# 0                                                  967.0
# 1                                                  968.0
# 2                                                  968.0
# 3                                                  969.0
# ...

# %%
df.shape
# Out:
# (69076, 25)

# %%
df1_col_f=df[["Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number","Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num"]]

# %%
df1_col_f
# Out:
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 69071                                                NaN
# 69072                                                NaN
# 69073                                                NaN
# 69074                                                NaN
# 69075                                                NaN
#
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# ...

# %%
df1_col_f.shape
# Out:
# (69076, 2)

# %%
df_fil=df1_col_f.dropna(subset=['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number','Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num'])

# %%
df_fil
# Out:
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number  \
# 77                                                 151.0
# 78                                                 215.0
# 79                                                 474.0
# 80                                                 663.0
# 81                                                 791.0
# ...                                                  ...
# 69000                                               69.0
# 69009                                               70.0
# 69037                                              151.0
# 69057                                              279.0
# 69058                                              279.0
#
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num
# 77                                                   9.0
# 78                                                   4.0
# 79                                                   3.0
# ...

# %%
df_fil.shape
# Out:
# (24633, 2)

# %%
df_fil.isnull().sum()
# Out:
# Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number    0
# Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num           0
# dtype: int64

# %%
df_fil['current_line']=(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number']*10)+(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num']*0.5)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_27928\3030596484.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['current_line']=(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number']*10)+(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num']*0.5)

# %%
df_fil.shape
# Out:
# (24633, 3)

# %%
df_fil.head()
# Out:
#     Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number  \
# 77                                              151.0
# 78                                              215.0
# 79                                              474.0
# 80                                              663.0
# 81                                              791.0
#
#     Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num  \
# 77                                                9.0
# 78                                                4.0
# 79                                                3.0
# 80                                                9.0
# 81                                                9.0
#
#     current_line
# 77        1514.5
# 78        2152.0
# 79        4741.5
# 80        6634.5
# 81        7914.5

# %%
df_fil['previous_line']=(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number'].shift(1)*10)+(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num'].shift(1)*0.5)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_27928\2726038280.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['previous_line']=(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number'].shift(1)*10)+(df_fil['Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num'].shift(1)*0.5)

# %%
df_fil.head()
# Out:
#     Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number  \
# 77                                              151.0
# 78                                              215.0
# 79                                              474.0
# 80                                              663.0
# 81                                              791.0
#
#     Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num  \
# 77                                                9.0
# 78                                                4.0
# 79                                                3.0
# 80                                                9.0
# 81                                                9.0
#
#     current_line  previous_line
# 77        1514.5            NaN
# 78        2152.0         1514.5
# 79        4741.5         2152.0
# 80        6634.5         4741.5
# 81        7914.5         6634.5

# %%
df_fil['delta']=(df_fil['current_line']-df_fil['previous_line'])/1.0
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_27928\4162976678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['delta']=(df_fil['current_line']-df_fil['previous_line'])/1.0

# %%
df_fil.shape
# Out:
# (24633, 5)

# %%
df_fil.head()
# Out:
#     Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number  \
# 77                                              151.0
# 78                                              215.0
# 79                                              474.0
# 80                                              663.0
# 81                                              791.0
#
#     Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num  \
# 77                                                9.0
# 78                                                4.0
# 79                                                3.0
# 80                                                9.0
# 81                                                9.0
#
#     current_line  previous_line   delta
# 77        1514.5            NaN     NaN
# 78        2152.0         1514.5   637.5
# 79        4741.5         2152.0  2589.5
# 80        6634.5         4741.5  1893.0
# 81        7914.5         6634.5  1280.0

# %%
df_fil['Lte_Delta_Pcell (RX_off)']=np.where(df_fil.current_line> df_fil.previous_line,((1023*10+19*0.5)-(df_fil.previous_line)) + (df_fil.current_line) / 0.5,((1023*10+9*1)-(df_fil.previous_line)) + (df_fil.current_line) / 1.0)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_27928\3595079508.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fil['Lte_Delta_Pcell (RX_off)']=np.where(df_fil.current_line> df_fil.previous_line,((1023*10+19*0.5)-(df_fil.previous_line)) + (df_fil.current_line) / 0.5,((1023*10+9*1)-(df_fil.previous_line)) + (df_fil.current_line) / 1.0)

# %%
df_fil.shape
# Out:
# (24633, 6)

# %%
df_fil.head()
# Out:
#     Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number  \
# 77                                              151.0
# 78                                              215.0
# 79                                              474.0
# 80                                              663.0
# 81                                              791.0
#
#     Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num  \
# 77                                                9.0
# 78                                                4.0
# 79                                                3.0
# 80                                                9.0
# 81                                                9.0
#
#     current_line  previous_line   delta  Lte_cell (RX_on)  \
# 77        1514.5            NaN     NaN               NaN
# 78        2152.0         1514.5   637.5           13029.0
# 79        4741.5         2152.0  2589.5           17570.5
# ...

# %%
df_fil
# Out:
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell System Frame Number  \
# 77                                                 151.0
# 78                                                 215.0
# 79                                                 474.0
# 80                                                 663.0
# 81                                                 791.0
# ...                                                  ...
# 69000                                               69.0
# 69009                                               70.0
# 69037                                              151.0
# 69057                                              279.0
# 69058                                              279.0
#
#        Qualcomm Lte/LteAdv ML1 PDSCH Stat Indication PCell Subframe Num  \
# 77                                                   9.0
# 78                                                   4.0
# 79                                                   3.0
# ...
